# %%
import json
import os

# %%
def inside_justifier(bbox_1:dict, bbox_2:dict):

    """
    Returns True if bbox_2 is inside bbox_1
    bbox_1 input format is dictionary
    bbox_1 = {'Left':0,
            'Top':0,
            'Width':10,
            'Height':10}
    bbox_2 is same as bbox_1
    """

    bbox_1_left = bbox_1['Left']
    bbox_1_top = bbox_1['Top']
    bbox_1_right = bbox_1['Left'] + bbox_1['Width']
    bbox_1_bottom = bbox_1['Top'] + bbox_1['Height']
    
    bbox_2_left = bbox_2['Left']
    bbox_2_top = bbox_2['Top']
    bbox_2_right = bbox_2['Left'] + bbox_2['Width']
    bbox_2_bottom = bbox_2['Top'] + bbox_2['Height']
    
    if (bbox_1_left <= bbox_2_left) and (bbox_1_top <= bbox_2_top):
        if (bbox_1_right >= bbox_2_right) and (bbox_1_bottom >= bbox_2_bottom):
            return True
    return False

# %%
x= "D:\\iDX_UNS\\idx_unstructured\\src\\outputs\\333699809 copy\\247f45c8-b485-46ff-9e43-a6ab911fcc79-02.json"

# %%
with open(x,'r') as file_:
    j=json.load(file_)

# %%
def table_data_validator(blocks):
    empty_cell_ids = []
    empty_sent_ids = []
    empty_word_ids = []
    cell_inside_table = []
    sent_inside_cell = []
    word_inside_sent=[]
    table_blocks = list(filter(lambda x : x['Type']=='Table',blocks))
    
    if len(table_blocks) >= 1:
        tables_found= True
        print('Tables Present!!')
        
        for t_block in table_blocks:
            child_list = t_block['Child']
            t_bbox = t_block['BoundingBox']
            
            for child in child_list:
                cell_filter = list(filter(lambda x:x['Id']==child, blocks))
                
                if len(cell_filter)>=1:
                    print('cell present!')
                    
                    for cell in cell_filter:
                        cell_child = cell['Child']
                        cell_bbox = cell['BoundingBox']
                        
                        if inside_justifier(t_bbox,cell_bbox):
                            for cell_id in cell_child:
                                sent = list(filter(lambda x:x['Id']==cell_id,blocks))

                                if len(sent) >= 1:
                                    print('Sentence present!!')

                                    for sentence in sent:
                                        sent_childs = sentence['Segments']
                                        sent_bbox = sentence['BoundingBox']
                                        if inside_justifier(cell_bbox,sent_bbox):
                                            
                                            for word_id in sent_childs:
                                                words = list(filter(lambda x:x['Id']==word_id,blocks))

                                                if len(words) >= 1:
                                                    print('words present!')
                                                    for word in words:
                                                        word_bbox = word['BoundingBox']
                                                        if inside_justifier(sent_bbox,word_bbox):
                                                            pass
                                                        else:
                                                            word_inside_sent.append(sent_id)
                                                            print('%%%%%% Not inside!!',sent_id)

                                                else:
                                                    empty_word_ids.append(word_id)
                                                    print('######### No words related!!',word_id)
                                        else:
                                            sent_inside_cell.append(cell_id)
                                            print('%%%%%% Not inside!!',cell_id)
                                else:
                                    empty_sent_ids.append(cell_id)
                                    print('######### No Sentences Found!!',cell_id)
                        else:
                            cell_inside_table.append(cell_child)
                            print('%%%%%% Not inside!!',cell_child)
                else:
                    empty_cell_ids.append(child)
                    print('######## No Cells Found!!',child)
    else:
        tables_found = False
        print('$$$$$$$$$$$ No Tables Found!!')
    if (len(cell_inside_table)<=0):
        cell_inside_tab =True
    else:
        cell_inside_tab = False
    if (len(sent_inside_cell)<=0):
        sent_inside_ce = True
    else:
        sent_inside_ce = False
    if (len(word_inside_sent)<=0):
        words_inside = True
    else:
        words_inside = False
    return tables_found,empty_cell_ids,empty_sent_ids,empty_word_ids,cell_inside_tab,sent_inside_ce,words_inside

# %%
a,b,c,d,e,f,g=table_data_validator(j['Blocks'])
# Out:
# Tables Present!!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! 21432914-55eb-4ee2-b812-b120d63b9ad9
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! ff4a01df-c1ac-49f2-8a7d-714ee92b49e5
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! 8c931a2b-2420-4556-a00f-ee88b4ca8d7a
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! 276d0e02-cbfa-4527-bde9-027a96938d99
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! 2a3dac27-b3a1-453e-95f4-37df9f3a26ef
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! f0c8e104-7f0d-4d56-a4d0-51e95584b765
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# Sentence present!!
# words present!
# ######## No Cells Found!! cd4de0bb-8c24-428c-be5f-25ef8c5e03e0
# cell present!
# Sentence present!!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!
# cell present!
# Sentence present!!
# words present!

# %%
a
# Out:
# True

# %%
b
# Out:
# ['21432914-55eb-4ee2-b812-b120d63b9ad9',
#  'ff4a01df-c1ac-49f2-8a7d-714ee92b49e5',
#  '8c931a2b-2420-4556-a00f-ee88b4ca8d7a',
#  '276d0e02-cbfa-4527-bde9-027a96938d99',
#  '2a3dac27-b3a1-453e-95f4-37df9f3a26ef',
#  'f0c8e104-7f0d-4d56-a4d0-51e95584b765',
#  'cd4de0bb-8c24-428c-be5f-25ef8c5e03e0']

# %%
c
# Out:
# []

# %%
d
# Out:
# []

# %%
e
# Out:
# True

# %%
f
# Out:
# True

# %%
g
# Out:
# True

# %%
path = "D:\\iDX_UNS\\idx_unstructured\\src\\outputs"

# %%
for file_path in os.listdir(path):
    path_ = os.path.splitext(file_path)[0]
    for internal in os.listdir(os.path.join(path,path_)):
        if os.path.splitext(internal)[1]=='.json':
            print(internal)
# Out:
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-01.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-02.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-03.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-04.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-05.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-06.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-07.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-08.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-09.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-10.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-11.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-12.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-13.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-01.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-02.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-03.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-04.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-05.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-06.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-07.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-08.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-09.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-10.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-11.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-12.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-13.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-01.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-02.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-03.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-04.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-05.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-06.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-07.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-08.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-09.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-10.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-11.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-12.json
# 247f45c8-b485-46ff-9e43-a6ab911fcc79-13.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-01.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-02.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-03.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-04.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-05.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-06.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-07.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-08.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-09.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-10.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-11.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-12.json
# 02500f0e-347c-4b2a-a36e-0c78e3517d3d-13.json
# fe926645-0d86-4cf5-8e8a-5c8e91eb3cbc-1.json
# fe926645-0d86-4cf5-8e8a-5c8e91eb3cbc-1.json
# 52ae04a0-b738-49b3-aab5-eed6d2906984-1.json
# 52ae04a0-b738-49b3-aab5-eed6d2906984-2.json
# 52ae04a0-b738-49b3-aab5-eed6d2906984-1.json
# 52ae04a0-b738-49b3-aab5-eed6d2906984-2.json
# 044a2348-d391-4390-9740-eed883caed8e-1.json
# 044a2348-d391-4390-9740-eed883caed8e-2.json
# 044a2348-d391-4390-9740-eed883caed8e-1.json
# 044a2348-d391-4390-9740-eed883caed8e-2.json
# 766f40b5-c7cf-4316-80e2-bc1dbc873361-1.json
# 766f40b5-c7cf-4316-80e2-bc1dbc873361-2.json
# 766f40b5-c7cf-4316-80e2-bc1dbc873361-1.json
# 766f40b5-c7cf-4316-80e2-bc1dbc873361-2.json
# 749fc4ee-6716-49d2-a434-f274080f4f68-1.json
# 749fc4ee-6716-49d2-a434-f274080f4f68-1.json
# 74024257-7028-470a-a7de-d52e0a33c621-01.json
# 74024257-7028-470a-a7de-d52e0a33c621-02.json
# 74024257-7028-470a-a7de-d52e0a33c621-03.json
# 74024257-7028-470a-a7de-d52e0a33c621-04.json
# 74024257-7028-470a-a7de-d52e0a33c621-05.json
# 74024257-7028-470a-a7de-d52e0a33c621-06.json
# 74024257-7028-470a-a7de-d52e0a33c621-07.json
